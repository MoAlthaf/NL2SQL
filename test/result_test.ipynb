# %%
import pandas as pd
import numpy as np

# %%
result_df=pd.read_csv('../result/results.csv')
false_df=result_df[result_df["matched"]==False]
#false_df.reset_index(inplace=True, drop=True)
false_df
# Out:
#                        db_id  \
# 10            concert_singer
# 11            concert_singer
# 17            concert_singer
# 25            concert_singer
# 31            concert_singer
# ...                      ...
# 1022                  singer
# 1023                  singer
# 1029                  singer
# 1032  real_estate_properties
# 1033  real_estate_properties
#
#                                             original_nl  \
# 10    Show all countries and the number of singers i...
# 11              How many singers are from each country?
# 17    What is the average and maximum capacities for...
# 25    What is the name and capacity of the stadium w...
# 31    Show names for all stadiums except for stadium...
# ...                                                 ...
# 1022  Show the names of singers that have more than ...
# 1023  What are the names of the singers that have mo...
# 1029  What are the citizenships that are shared by s...
# ...

# %%
index=2
print(false_df.iloc[index]["original_nl"])
print(false_df.iloc[index]["paraphrased_nl"])
print(false_df.iloc[index]["gt_nl"])
print(false_df.iloc[index]["generated_sql"])
# Out:
# What is the average and maximum capacities for all stadiums ?
# What are the mean and highest capacities for each stadium across all locations?
# SELECT avg(capacity) ,  max(capacity) FROM stadium
# SELECT s.name AS stadium_name, AVG(s.capacity) AS mean_capacity, MAX(s.capacity) AS highest_capacity FROM stadium s GROUP BY s.name;

# %%
attempst_df=result_df[result_df["attempts"]>1]
attempst_df.reset_index(inplace=True, drop=True)
attempst_df.shape
# Out:
# (27, 7)
